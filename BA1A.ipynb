# %%
str = input()
s=""
for i in range(len(str)):
  if str [i] == 'A':
     s += 'T'
  elif str[i] == 'T':
    s += 'A'
  elif str [i] =='C':
    s +='G'
  elif str[i] == 'G':
    s += 'C'


s = s[::-1]

print(s)
# Out:
# ...
# ...
